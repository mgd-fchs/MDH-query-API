# %%
import os
import pandas as pd
import requests
import datetime
from dateutil import parser
import time

# %%
API_TOKEN = os.getenv('UH_API_TOKEN')
SHARING_CODE = os.getenv('UH_PARTNER_SHARING_CODE')

# %%
PARTICIPANT_EMAILS = [
    "magdalena.h.fuchs@gmail.com",
    "victoria-brugger@hotmail.com",
    "gtrskh7yjz@privaterelay.appleid.com"
]

# %%
import datetime
import requests

BASE_URL = "https://partner.ultrahuman.com/api/v1/metrics"


def fetch_metrics(email, _date_str_ignored):
    # Always fetch yesterday
    yesterday = datetime.date.today() - datetime.timedelta(days=1)
    date_str = yesterday.strftime("%d/%m/%Y")   # UH expects DD/MM/YYYY

    params = {"email": email, "date": date_str}
    headers = {"Authorization": API_TOKEN}

    resp = requests.get(BASE_URL, params=params, headers=headers, timeout=20)
    resp.raise_for_status()
    return resp.json()


def has_real_data(metric_entry):
    if not isinstance(metric_entry, dict):
        return False

    obj = metric_entry.get("object")
    if not isinstance(obj, dict):
        return False

    if obj.get("value") not in (None, "", []):
        return True

    values = obj.get("values")
    if isinstance(values, list) and len(values) > 0:
        return True

    return False


def filter_non_empty(metric_data):
    if not isinstance(metric_data, list):
        return []

    out = []
    for m in metric_data:
        if not isinstance(m, dict):
            continue
        if m.get("type") == "vo2_max":
            continue
        if has_real_data(m):
            out.append(m)
    return out


def extract_metric_data(api_response):
    if not isinstance(api_response, dict):
        return []
    data = api_response.get("data")
    if not isinstance(data, dict):
        return []
    metric_data = data.get("metric_data")
    if not isinstance(metric_data, list):
        return []
    return metric_data


def within_last_25h(metric_entry, cutoff_ts):
    """Keep only metrics whose object timestamps fall within the last 25 hours."""
    if not isinstance(metric_entry, dict):
        return False

    obj = metric_entry.get("object", {})
    if not isinstance(obj, dict):
        return False

    ts = obj.get("day_start_timestamp")
    if not isinstance(ts, (int, float)):
        return False

    # Ultrahuman timestamps appear to be in seconds
    return ts >= cutoff_ts


def fetch_last_day_all():
    yesterday = datetime.date.today() - datetime.timedelta(days=1)
    date_str = yesterday.strftime("%d/%m/%Y")

    result = {}

    for email in PARTICIPANT_EMAILS:
        records = []
        any_data = False

        try:
            resp = fetch_metrics(email, date_str)
            raw = extract_metric_data(resp)

            # Only apply your metric-level filtering (non-empty + skip vo2_max)
            non_empty = filter_non_empty(raw)

            if non_empty:
                any_data = True

            records.append({
                "date": date_str,
                "metric_data": non_empty
            })

        except Exception as e:
            records.append({
                "date": date_str,
                "error": str(e),
                "metric_data": []
            })

        result[email] = {"records": records, "has_data": any_data}

    return result

# %%
res = fetch_last_day_all()
res
# Out:
# {'magdalena.h.fuchs@gmail.com': {'records': [{'date': '01/12/2025',
#     'metric_data': []}],
#   'has_data': False},
#  'victoria-brugger@hotmail.com': {'records': [{'date': '01/12/2025',
#     'metric_data': []}],
#   'has_data': False},
#  'gtrskh7yjz@privaterelay.appleid.com': {'records': [{'date': '01/12/2025',
#     'metric_data': [{'type': 'hr',
#       'object': {'day_start_timestamp': 1764543600,
#        'title': 'Heart Rate',
#        'values': [{'value': 124, 'timestamp': 1764577699},
#         {'value': 112, 'timestamp': 1764577999}],
#        'last_reading': 112,
#        'unit': 'BPM'}},
#      {'type': 'temp',
#       'object': {'day_start_timestamp': 1764543600,
#        'title': 'Skin Temperature',
#        'values': [{'value': 29.91410064697266, 'timestamp': 1764577844},
#         {'value': 32.45837020874023, 'timestamp': 1764578144}],
#        'last_reading': 32,
#        'unit': '°C'}},
#      {'type': 'steps',
#       'object': {'day_start_timestamp': 1764543600,
#        'values': [{'value': 0.0, 'timestamp': 1764543643},
#         {'value': 0.0, 'timestamp': 1764543943},
#         {'value': 0.0, 'timestamp': 1764544243},
#         {'value': 0.0, 'timestamp': 1764544543},
#         {'value': 0.0, 'timestamp': 1764544843},
#         {'value': 0.0, 'timestamp': 1764545143},
#         {'value': 0.0, 'timestamp': 1764545443},
#         {'value': 0.0, 'timestamp': 1764545743},
#         {'value': 0.0, 'timestamp': 1764546043},
#         {'value': 0.0, 'timestamp': 1764546343},
#         {'value': 0.0, 'timestamp': 1764546643},
#         {'value': 0.0, 'timestamp': 1764546943},
#         {'value': 0.0, 'timestamp': 1764547243},
#         {'value': 0.0, 'timestamp': 1764547543},
#         {'value': 0.0, 'timestamp': 1764547843},
#         {'value': 0.0, 'timestamp': 1764548143},
#         {'value': 0.0, 'timestamp': 1764548443},
#         {'value': 0.0, 'timestamp': 1764548743},
#         {'value': 0.0, 'timestamp': 1764549043},
#         {'value': 0.0, 'timestamp': 1764549343},
#         {'value': 0.0, 'timestamp': 1764549643},
#         {'value': 0.0, 'timestamp': 1764549943},
#         {'value': 0.0, 'timestamp': 1764550243},
#         {'value': 0.0, 'timestamp': 1764550543},
#         {'value': 0.0, 'timestamp': 1764550843},
#         {'value': 0.0, 'timestamp': 1764551143},
#         {'value': 0.0, 'timestamp': 1764551443},
#         {'value': 0.0, 'timestamp': 1764551743},
#         {'value': 0.0, 'timestamp': 1764552043},
#         {'value': 0.0, 'timestamp': 1764552343},
#         {'value': 0.0, 'timestamp': 1764552643},
#         {'value': 0.0, 'timestamp': 1764552943},
#         {'value': 0.0, 'timestamp': 1764553243},
#         {'value': 0.0, 'timestamp': 1764553543},
#         {'value': 0.0, 'timestamp': 1764553843},
#         {'value': 0.0, 'timestamp': 1764554143},
#         {'value': 0.0, 'timestamp': 1764554443},
#         {'value': 0.0, 'timestamp': 1764554743},
#         {'value': 0.0, 'timestamp': 1764555043},
#         {'value': 0.0, 'timestamp': 1764555343},
#         {'value': 0.0, 'timestamp': 1764555643},
#         {'value': 0.0, 'timestamp': 1764555943},
#         {'value': 0.0, 'timestamp': 1764556243},
#         {'value': 0.0, 'timestamp': 1764556543},
#         {'value': 0.0, 'timestamp': 1764556843},
#         {'value': 0.0, 'timestamp': 1764557143},
#         {'value': 0.0, 'timestamp': 1764557443},
#         {'value': 0.0, 'timestamp': 1764557743},
#         {'value': 0.0, 'timestamp': 1764558043},
#         {'value': 0.0, 'timestamp': 1764558343},
#         {'value': 0.0, 'timestamp': 1764558643},
#         {'value': 0.0, 'timestamp': 1764558943},
#         {'value': 0.0, 'timestamp': 1764559243},
#         {'value': 0.0, 'timestamp': 1764559543},
#         {'value': 0.0, 'timestamp': 1764559843},
#         {'value': 0.0, 'timestamp': 1764560143},
#         {'value': 0.0, 'timestamp': 1764560443},
#         {'value': 0.0, 'timestamp': 1764560743},
#         {'value': 0.0, 'timestamp': 1764561043},
#         {'value': 0.0, 'timestamp': 1764561343},
#         {'value': 0.0, 'timestamp': 1764561643},
#         {'value': 0.0, 'timestamp': 1764561943},
#         {'value': 0.0, 'timestamp': 1764562243},
#         {'value': 0.0, 'timestamp': 1764562543},
#         {'value': 0.0, 'timestamp': 1764562843},
#         {'value': 0.0, 'timestamp': 1764563143},
#         {'value': 0.0, 'timestamp': 1764563443},
#         {'value': 0.0, 'timestamp': 1764563743},
#         {'value': 0.0, 'timestamp': 1764564043},
#         {'value': 0.0, 'timestamp': 1764564343},
#         {'value': 0.0, 'timestamp': 1764564643},
#         {'value': 0.0, 'timestamp': 1764564943},
#         {'value': 0.0, 'timestamp': 1764565243},
#         {'value': 0.0, 'timestamp': 1764565543},
#         {'value': 0.0, 'timestamp': 1764565843},
#         {'value': 0.0, 'timestamp': 1764566143},
#         {'value': 0.0, 'timestamp': 1764566443},
#         {'value': 0.0, 'timestamp': 1764566743},
#         {'value': 0.0, 'timestamp': 1764567043},
#         {'value': 0.0, 'timestamp': 1764567343},
#         {'value': 0.0, 'timestamp': 1764567643},
#         {'value': 0.0, 'timestamp': 1764567943},
#         {'value': 0.0, 'timestamp': 1764568243},
#         {'value': 0.0, 'timestamp': 1764568543},
#         {'value': 0.0, 'timestamp': 1764568843},
#         {'value': 0.0, 'timestamp': 1764569143},
#         {'value': 0.0, 'timestamp': 1764569443},
#         {'value': 0.0, 'timestamp': 1764569743},
#         {'value': 0.0, 'timestamp': 1764570043},
#         {'value': 0.0, 'timestamp': 1764570343},
#         {'value': 0.0, 'timestamp': 1764570643},
#         {'value': 0.0, 'timestamp': 1764570943},
#         {'value': 0.0, 'timestamp': 1764571243},
#         {'value': 0.0, 'timestamp': 1764571543},
#         {'value': 0.0, 'timestamp': 1764571843},
#         {'value': 0.0, 'timestamp': 1764572143},
#         {'value': 0.0, 'timestamp': 1764572443},
#         {'value': 0.0, 'timestamp': 1764572743},
#         {'value': 0.0, 'timestamp': 1764573043},
#         {'value': 0.0, 'timestamp': 1764573343},
#         {'value': 0.0, 'timestamp': 1764573643},
#         {'value': 0.0, 'timestamp': 1764573943},
#         {'value': 0.0, 'timestamp': 1764574243},
#         {'value': 0.0, 'timestamp': 1764574543},
#         {'value': 0.0, 'timestamp': 1764574843},
#         {'value': 0.0, 'timestamp': 1764575143},
#         {'value': 0.0, 'timestamp': 1764575443},
#         {'value': 0.0, 'timestamp': 1764575743},
#         {'value': 0.0, 'timestamp': 1764576043},
#         {'value': 0.0, 'timestamp': 1764576343},
#         {'value': 0.0, 'timestamp': 1764576643},
#         {'value': 0.0, 'timestamp': 1764576943},
#         {'value': 0.0, 'timestamp': 1764577243},
#         {'value': 0.0, 'timestamp': 1764577543},
#         {'value': 263.0, 'timestamp': 1764577844},
#         {'value': 433.0, 'timestamp': 1764578144},
#         {'value': 0.0, 'timestamp': 1764578444},
#         {'value': 0.0, 'timestamp': 1764578744},
#         {'value': 0.0, 'timestamp': 1764579044},
#         {'value': 0.0, 'timestamp': 1764579344},
#         {'value': 0.0, 'timestamp': 1764579644},
#         {'value': 0.0, 'timestamp': 1764579944},
#         {'value': 0.0, 'timestamp': 1764580244},
#         {'value': 0.0, 'timestamp': 1764580544},
#         {'value': 0.0, 'timestamp': 1764580844},
#         {'value': 0.0, 'timestamp': 1764581144},
#         {'value': 0.0, 'timestamp': 1764581444},
#         {'value': 0.0, 'timestamp': 1764581743},
#         {'value': 0.0, 'timestamp': 1764582043},
#         {'value': 0.0, 'timestamp': 1764582343},
#         {'value': 0.0, 'timestamp': 1764582643},
#         {'value': 0.0, 'timestamp': 1764582943},
#         {'value': 0.0, 'timestamp': 1764583243},
#         {'value': 0.0, 'timestamp': 1764583543},
#         {'value': 0.0, 'timestamp': 1764583843},
#         {'value': 0.0, 'timestamp': 1764584143},
#         {'value': 0.0, 'timestamp': 1764584443},
#         {'value': 0.0, 'timestamp': 1764584743},
#         {'value': 0.0, 'timestamp': 1764585043},
#         {'value': 0.0, 'timestamp': 1764585343},
#         {'value': 0.0, 'timestamp': 1764585643},
#         {'value': 0.0, 'timestamp': 1764585943},
#         {'value': 0.0, 'timestamp': 1764586243},
#         {'value': 0.0, 'timestamp': 1764586543},
#         {'value': 0.0, 'timestamp': 1764586843},
#         {'value': 0.0, 'timestamp': 1764587143},
#         {'value': 0.0, 'timestamp': 1764587443},
#         {'value': 0.0, 'timestamp': 1764587743},
#         {'value': 0.0, 'timestamp': 1764588043},
#         {'value': 0.0, 'timestamp': 1764588343},
#         {'value': 0.0, 'timestamp': 1764588643},
#         {'value': 0.0, 'timestamp': 1764588943},
#         {'value': 0.0, 'timestamp': 1764589243},
#         {'value': 0.0, 'timestamp': 1764589543},
#         {'value': 0.0, 'timestamp': 1764589843},
#         {'value': 0.0, 'timestamp': 1764590143},
#         {'value': 0.0, 'timestamp': 1764590443},
#         {'value': 0.0, 'timestamp': 1764590743},
#         {'value': 0.0, 'timestamp': 1764591043},
#         {'value': 0.0, 'timestamp': 1764591343},
#         {'value': 0.0, 'timestamp': 1764591643},
#         {'value': 0.0, 'timestamp': 1764591943},
#         {'value': 0.0, 'timestamp': 1764592243},
#         {'value': 0.0, 'timestamp': 1764592543},
#         {'value': 0.0, 'timestamp': 1764592843},
#         {'value': 0.0, 'timestamp': 1764593143},
#         {'value': 0.0, 'timestamp': 1764593443},
#         {'value': 0.0, 'timestamp': 1764593743},
#         {'value': 0.0, 'timestamp': 1764594043},
#         {'value': 0.0, 'timestamp': 1764594343},
#         {'value': 0.0, 'timestamp': 1764594643},
#         {'value': 0.0, 'timestamp': 1764594943},
#         {'value': 0.0, 'timestamp': 1764595243},
#         {'value': 0.0, 'timestamp': 1764595543},
#         {'value': 0.0, 'timestamp': 1764595843},
#         {'value': 0.0, 'timestamp': 1764596143},
#         {'value': 0.0, 'timestamp': 1764596443},
#         {'value': 0.0, 'timestamp': 1764596743},
#         {'value': 0.0, 'timestamp': 1764597043},
#         {'value': 0.0, 'timestamp': 1764597343},
#         {'value': 0.0, 'timestamp': 1764597643},
#         {'value': 0.0, 'timestamp': 1764597943},
#         {'value': 0.0, 'timestamp': 1764598243},
#         {'value': 0.0, 'timestamp': 1764598543},
#         {'value': 0.0, 'timestamp': 1764598843},
#         {'value': 0.0, 'timestamp': 1764599143},
#         {'value': 0.0, 'timestamp': 1764599443},
#         {'value': 0.0, 'timestamp': 1764599743},
#         {'value': 0.0, 'timestamp': 1764600043},
#         {'value': 0.0, 'timestamp': 1764600343},
#         {'value': 0.0, 'timestamp': 1764600643},
#         {'value': 0.0, 'timestamp': 1764600943},
#         {'value': 0.0, 'timestamp': 1764601243},
#         {'value': 0.0, 'timestamp': 1764601543},
#         {'value': 0.0, 'timestamp': 1764601843},
#         {'value': 0.0, 'timestamp': 1764602143},
#         {'value': 0.0, 'timestamp': 1764602443},
#         {'value': 0.0, 'timestamp': 1764602743},
#         {'value': 0.0, 'timestamp': 1764603043},
#         {'value': 0.0, 'timestamp': 1764603343},
#         {'value': 0.0, 'timestamp': 1764603643},
#         {'value': 0.0, 'timestamp': 1764603943},
#         {'value': 0.0, 'timestamp': 1764604243},
#         {'value': 0.0, 'timestamp': 1764604543},
#         {'value': 0.0, 'timestamp': 1764604843},
#         {'value': 0.0, 'timestamp': 1764605143},
#         {'value': 0.0, 'timestamp': 1764605443},
#         {'value': 0.0, 'timestamp': 1764605743},
#         {'value': 0.0, 'timestamp': 1764606043},
#         {'value': 0.0, 'timestamp': 1764606343},
#         {'value': 0.0, 'timestamp': 1764606643},
#         {'value': 0.0, 'timestamp': 1764606943},
#         {'value': 0.0, 'timestamp': 1764607243},
#         {'value': 0.0, 'timestamp': 1764607543},
#         {'value': 0.0, 'timestamp': 1764607843},
#         {'value': 0.0, 'timestamp': 1764608143},
#         {'value': 0.0, 'timestamp': 1764608443},
#         {'value': 0.0, 'timestamp': 1764608743},
#         {'value': 0.0, 'timestamp': 1764609043},
#         {'value': 0.0, 'timestamp': 1764609343},
#         {'value': 0.0, 'timestamp': 1764609643},
#         {'value': 0.0, 'timestamp': 1764609943},
#         {'value': 0.0, 'timestamp': 1764610243},
#         {'value': 0.0, 'timestamp': 1764610543},
#         {'value': 0.0, 'timestamp': 1764610843},
#         {'value': 0.0, 'timestamp': 1764611143},
#         {'value': 0.0, 'timestamp': 1764611443},
#         {'value': 0.0, 'timestamp': 1764611743},
#         {'value': 0.0, 'timestamp': 1764612043},
#         {'value': 0.0, 'timestamp': 1764612343},
#         {'value': 0.0, 'timestamp': 1764612643},
#         {'value': 0.0, 'timestamp': 1764612943},
#         {'value': 0.0, 'timestamp': 1764613243},
#         {'value': 0.0, 'timestamp': 1764613543},
#         {'value': 0.0, 'timestamp': 1764613843},
#         {'value': 0.0, 'timestamp': 1764614143},
#         {'value': 0.0, 'timestamp': 1764614443},
#         {'value': 0.0, 'timestamp': 1764614743},
#         {'value': 0.0, 'timestamp': 1764615043},
#         {'value': 0.0, 'timestamp': 1764615343},
#         {'value': 0.0, 'timestamp': 1764615643},
#         {'value': 0.0, 'timestamp': 1764615943},
#         {'value': 0.0, 'timestamp': 1764616243},
#         {'value': 0.0, 'timestamp': 1764616543},
#         {'value': 0.0, 'timestamp': 1764616843},
#         {'value': 0.0, 'timestamp': 1764617143},
#         {'value': 0.0, 'timestamp': 1764617443},
#         {'value': 0.0, 'timestamp': 1764617743},
#         {'value': 0.0, 'timestamp': 1764618043},
#         {'value': 0.0, 'timestamp': 1764618343},
#         {'value': 0.0, 'timestamp': 1764618643},
#         {'value': 0.0, 'timestamp': 1764618943},
#         {'value': 0.0, 'timestamp': 1764619243},
#         {'value': 0.0, 'timestamp': 1764619543},
#         {'value': 0.0, 'timestamp': 1764619843},
#         {'value': 0.0, 'timestamp': 1764620143},
#         {'value': 0.0, 'timestamp': 1764620443},
#         {'value': 0.0, 'timestamp': 1764620743},
#         {'value': 0.0, 'timestamp': 1764621043},
#         {'value': 0.0, 'timestamp': 1764621343},
#         {'value': 0.0, 'timestamp': 1764621643},
#         {'value': 0.0, 'timestamp': 1764621943},
#         {'value': 0.0, 'timestamp': 1764622243},
#         {'value': 0.0, 'timestamp': 1764622543},
#         {'value': 0.0, 'timestamp': 1764622843},
#         {'value': 0.0, 'timestamp': 1764623143},
#         {'value': 0.0, 'timestamp': 1764623443},
#         {'value': 0.0, 'timestamp': 1764623743},
#         {'value': 0.0, 'timestamp': 1764624043},
#         {'value': 0.0, 'timestamp': 1764624343},
#         {'value': 0.0, 'timestamp': 1764624643},
#         {'value': 0.0, 'timestamp': 1764624943},
#         {'value': 0.0, 'timestamp': 1764625243},
#         {'value': 0.0, 'timestamp': 1764625543},
#         {'value': 0.0, 'timestamp': 1764625843},
#         {'value': 0.0, 'timestamp': 1764626143},
#         {'value': 0.0, 'timestamp': 1764626443},
#         {'value': 0.0, 'timestamp': 1764626743},
#         {'value': 0.0, 'timestamp': 1764627043},
#         {'value': 0.0, 'timestamp': 1764627343},
#         {'value': 0.0, 'timestamp': 1764627643},
#         {'value': 0.0, 'timestamp': 1764627943},
#         {'value': 0.0, 'timestamp': 1764628243},
#         {'value': 0.0, 'timestamp': 1764628543},
#         {'value': 0.0, 'timestamp': 1764628843},
#         {'value': 0.0, 'timestamp': 1764629143},
#         {'value': 0.0, 'timestamp': 1764629443},
#         {'value': 0.0, 'timestamp': 1764629743}],
#        'subtitle': 'Average',
#        'total': 696.0,
#        'avg': 2.416666666666667,
#        'trend_title': '+2',
#        'trend_direction': 'positive'}},
#      {'type': 'night_rhr',
#       'object': {'day_start_timestamp': 1764543600,
#        'title': 'Resting HR',
#        'values': [{'value': None, 'timestamp': 1764543600}],
#        'subtitle': 'Sleep Time Average'}},
#      {'type': 'movement_index',
#       'object': {'value': 60,
#        'title': 'Movement Index',
#        'day_start_timestamp': 1764543600}}]}],
#   'has_data': True}}

# %%
import csv
import json
import io
import os


def slugify_email(email: str) -> str:
    return (
        email.replace("@", "_at_")
        .replace("+", "_plus_")
        .replace("/", "_")
        .replace("\\", "_")
    )


def expand_metric_to_rows(email: str, date_str: str, metric: dict):
    """Convert one metric object into 0..N CSV rows."""
    rows = []
    metric_type = metric.get("type", "")
    obj = metric.get("object", {}) or {}

    # Skip vo2_max globally
    if metric_type == "vo2_max":
        return rows

    # Case 1: Time-series data (most important)
    values = obj.get("values")
    if isinstance(values, list) and len(values) > 0:
        for item in values:
            if not isinstance(item, dict):
                continue
            ts = item.get("timestamp")
            val = item.get("value")

            rows.append(
                {
                    "email": email,
                    "date": date_str,
                    "metric_type": metric_type,
                    "timestamp": ts,
                    "value": val,
                }
            )
        return rows

    # Case 2: Single summary value
    if obj.get("value") not in (None, "", []):
        rows.append(
            {
                "email": email,
                "date": date_str,
                "metric_type": metric_type,
                "timestamp": obj.get("day_start_timestamp", ""),
                "value": obj.get("value"),
            }
        )
        return rows

    # Case 3: No datapoints → no rows
    return rows


def metrics_to_rows_longformat(email: str, date_str: str, metrics: list[dict]):
    """Flatten all metric objects into a long-format CSV-ready list."""
    all_rows = []
    for metric in metrics:
        if not isinstance(metric, dict):
            continue
        expanded = expand_metric_to_rows(email, date_str, metric)
        all_rows.extend(expanded)
    return all_rows


def save_results_as_csv(results, output_dir="./uh_output"):
    os.makedirs(output_dir, exist_ok=True)

    for email, content in results.items():
        email_slug = slugify_email(email)

        for entry in content["records"]:
            date_str = entry["date"]  # DD/MM/YYYY

            # Convert DD/MM/YYYY to usable components
            d, m, y = date_str.split("/")  # day, month, year

            # Folder name: YYYY_MM
            month_folder = f"{y}_{m}"
            folder_path = os.path.join(output_dir, month_folder)
            os.makedirs(folder_path, exist_ok=True)

            # Filename-safe version of the date: YYYY-MM-DD
            safe_date = f"{y}-{m}-{d}"

            metrics = entry.get("metric_data", [])
            rows = metrics_to_rows_longformat(email, date_str, metrics)

            filename = f"{safe_date}_{email_slug}.csv"
            filepath = os.path.join(folder_path, filename)

            with open(filepath, "w", newline="", encoding="utf-8") as f:
                writer = csv.DictWriter(
                    f,
                    fieldnames=["email", "date", "metric_type", "timestamp", "value"],
                )
                writer.writeheader()
                for r in rows:
                    writer.writerow(r)

# %%
results = fetch_last_day_all()
results
# Out:
# {'magdalena.h.fuchs@gmail.com': {'records': [{'date': '01/12/2025',
#     'metric_data': []}],
#   'has_data': False},
#  'victoria-brugger@hotmail.com': {'records': [{'date': '01/12/2025',
#     'metric_data': []}],
#   'has_data': False},
#  'gtrskh7yjz@privaterelay.appleid.com': {'records': [{'date': '01/12/2025',
#     'metric_data': [{'type': 'hr',
#       'object': {'day_start_timestamp': 1764543600,
#        'title': 'Heart Rate',
#        'values': [{'value': 124, 'timestamp': 1764577699},
#         {'value': 112, 'timestamp': 1764577999}],
#        'last_reading': 112,
#        'unit': 'BPM'}},
#      {'type': 'temp',
#       'object': {'day_start_timestamp': 1764543600,
#        'title': 'Skin Temperature',
#        'values': [{'value': 29.91410064697266, 'timestamp': 1764577844},
#         {'value': 32.45837020874023, 'timestamp': 1764578144}],
#        'last_reading': 32,
#        'unit': '°C'}},
#      {'type': 'steps',
#       'object': {'day_start_timestamp': 1764543600,
#        'values': [{'value': 0.0, 'timestamp': 1764543643},
#         {'value': 0.0, 'timestamp': 1764543943},
#         {'value': 0.0, 'timestamp': 1764544243},
#         {'value': 0.0, 'timestamp': 1764544543},
#         {'value': 0.0, 'timestamp': 1764544843},
#         {'value': 0.0, 'timestamp': 1764545143},
#         {'value': 0.0, 'timestamp': 1764545443},
#         {'value': 0.0, 'timestamp': 1764545743},
#         {'value': 0.0, 'timestamp': 1764546043},
#         {'value': 0.0, 'timestamp': 1764546343},
#         {'value': 0.0, 'timestamp': 1764546643},
#         {'value': 0.0, 'timestamp': 1764546943},
#         {'value': 0.0, 'timestamp': 1764547243},
#         {'value': 0.0, 'timestamp': 1764547543},
#         {'value': 0.0, 'timestamp': 1764547843},
#         {'value': 0.0, 'timestamp': 1764548143},
#         {'value': 0.0, 'timestamp': 1764548443},
#         {'value': 0.0, 'timestamp': 1764548743},
#         {'value': 0.0, 'timestamp': 1764549043},
#         {'value': 0.0, 'timestamp': 1764549343},
#         {'value': 0.0, 'timestamp': 1764549643},
#         {'value': 0.0, 'timestamp': 1764549943},
#         {'value': 0.0, 'timestamp': 1764550243},
#         {'value': 0.0, 'timestamp': 1764550543},
#         {'value': 0.0, 'timestamp': 1764550843},
#         {'value': 0.0, 'timestamp': 1764551143},
#         {'value': 0.0, 'timestamp': 1764551443},
#         {'value': 0.0, 'timestamp': 1764551743},
#         {'value': 0.0, 'timestamp': 1764552043},
#         {'value': 0.0, 'timestamp': 1764552343},
#         {'value': 0.0, 'timestamp': 1764552643},
#         {'value': 0.0, 'timestamp': 1764552943},
#         {'value': 0.0, 'timestamp': 1764553243},
#         {'value': 0.0, 'timestamp': 1764553543},
#         {'value': 0.0, 'timestamp': 1764553843},
#         {'value': 0.0, 'timestamp': 1764554143},
#         {'value': 0.0, 'timestamp': 1764554443},
#         {'value': 0.0, 'timestamp': 1764554743},
#         {'value': 0.0, 'timestamp': 1764555043},
#         {'value': 0.0, 'timestamp': 1764555343},
#         {'value': 0.0, 'timestamp': 1764555643},
#         {'value': 0.0, 'timestamp': 1764555943},
#         {'value': 0.0, 'timestamp': 1764556243},
#         {'value': 0.0, 'timestamp': 1764556543},
#         {'value': 0.0, 'timestamp': 1764556843},
#         {'value': 0.0, 'timestamp': 1764557143},
#         {'value': 0.0, 'timestamp': 1764557443},
#         {'value': 0.0, 'timestamp': 1764557743},
#         {'value': 0.0, 'timestamp': 1764558043},
#         {'value': 0.0, 'timestamp': 1764558343},
#         {'value': 0.0, 'timestamp': 1764558643},
#         {'value': 0.0, 'timestamp': 1764558943},
#         {'value': 0.0, 'timestamp': 1764559243},
#         {'value': 0.0, 'timestamp': 1764559543},
#         {'value': 0.0, 'timestamp': 1764559843},
#         {'value': 0.0, 'timestamp': 1764560143},
#         {'value': 0.0, 'timestamp': 1764560443},
#         {'value': 0.0, 'timestamp': 1764560743},
#         {'value': 0.0, 'timestamp': 1764561043},
#         {'value': 0.0, 'timestamp': 1764561343},
#         {'value': 0.0, 'timestamp': 1764561643},
#         {'value': 0.0, 'timestamp': 1764561943},
#         {'value': 0.0, 'timestamp': 1764562243},
#         {'value': 0.0, 'timestamp': 1764562543},
#         {'value': 0.0, 'timestamp': 1764562843},
#         {'value': 0.0, 'timestamp': 1764563143},
#         {'value': 0.0, 'timestamp': 1764563443},
#         {'value': 0.0, 'timestamp': 1764563743},
#         {'value': 0.0, 'timestamp': 1764564043},
#         {'value': 0.0, 'timestamp': 1764564343},
#         {'value': 0.0, 'timestamp': 1764564643},
#         {'value': 0.0, 'timestamp': 1764564943},
#         {'value': 0.0, 'timestamp': 1764565243},
#         {'value': 0.0, 'timestamp': 1764565543},
#         {'value': 0.0, 'timestamp': 1764565843},
#         {'value': 0.0, 'timestamp': 1764566143},
#         {'value': 0.0, 'timestamp': 1764566443},
#         {'value': 0.0, 'timestamp': 1764566743},
#         {'value': 0.0, 'timestamp': 1764567043},
#         {'value': 0.0, 'timestamp': 1764567343},
#         {'value': 0.0, 'timestamp': 1764567643},
#         {'value': 0.0, 'timestamp': 1764567943},
#         {'value': 0.0, 'timestamp': 1764568243},
#         {'value': 0.0, 'timestamp': 1764568543},
#         {'value': 0.0, 'timestamp': 1764568843},
#         {'value': 0.0, 'timestamp': 1764569143},
#         {'value': 0.0, 'timestamp': 1764569443},
#         {'value': 0.0, 'timestamp': 1764569743},
#         {'value': 0.0, 'timestamp': 1764570043},
#         {'value': 0.0, 'timestamp': 1764570343},
#         {'value': 0.0, 'timestamp': 1764570643},
#         {'value': 0.0, 'timestamp': 1764570943},
#         {'value': 0.0, 'timestamp': 1764571243},
#         {'value': 0.0, 'timestamp': 1764571543},
#         {'value': 0.0, 'timestamp': 1764571843},
#         {'value': 0.0, 'timestamp': 1764572143},
#         {'value': 0.0, 'timestamp': 1764572443},
#         {'value': 0.0, 'timestamp': 1764572743},
#         {'value': 0.0, 'timestamp': 1764573043},
#         {'value': 0.0, 'timestamp': 1764573343},
#         {'value': 0.0, 'timestamp': 1764573643},
#         {'value': 0.0, 'timestamp': 1764573943},
#         {'value': 0.0, 'timestamp': 1764574243},
#         {'value': 0.0, 'timestamp': 1764574543},
#         {'value': 0.0, 'timestamp': 1764574843},
#         {'value': 0.0, 'timestamp': 1764575143},
#         {'value': 0.0, 'timestamp': 1764575443},
#         {'value': 0.0, 'timestamp': 1764575743},
#         {'value': 0.0, 'timestamp': 1764576043},
#         {'value': 0.0, 'timestamp': 1764576343},
#         {'value': 0.0, 'timestamp': 1764576643},
#         {'value': 0.0, 'timestamp': 1764576943},
#         {'value': 0.0, 'timestamp': 1764577243},
#         {'value': 0.0, 'timestamp': 1764577543},
#         {'value': 263.0, 'timestamp': 1764577844},
#         {'value': 433.0, 'timestamp': 1764578144},
#         {'value': 0.0, 'timestamp': 1764578444},
#         {'value': 0.0, 'timestamp': 1764578744},
#         {'value': 0.0, 'timestamp': 1764579044},
#         {'value': 0.0, 'timestamp': 1764579344},
#         {'value': 0.0, 'timestamp': 1764579644},
#         {'value': 0.0, 'timestamp': 1764579944},
#         {'value': 0.0, 'timestamp': 1764580244},
#         {'value': 0.0, 'timestamp': 1764580544},
#         {'value': 0.0, 'timestamp': 1764580844},
#         {'value': 0.0, 'timestamp': 1764581144},
#         {'value': 0.0, 'timestamp': 1764581444},
#         {'value': 0.0, 'timestamp': 1764581743},
#         {'value': 0.0, 'timestamp': 1764582043},
#         {'value': 0.0, 'timestamp': 1764582343},
#         {'value': 0.0, 'timestamp': 1764582643},
#         {'value': 0.0, 'timestamp': 1764582943},
#         {'value': 0.0, 'timestamp': 1764583243},
#         {'value': 0.0, 'timestamp': 1764583543},
#         {'value': 0.0, 'timestamp': 1764583843},
#         {'value': 0.0, 'timestamp': 1764584143},
#         {'value': 0.0, 'timestamp': 1764584443},
#         {'value': 0.0, 'timestamp': 1764584743},
#         {'value': 0.0, 'timestamp': 1764585043},
#         {'value': 0.0, 'timestamp': 1764585343},
#         {'value': 0.0, 'timestamp': 1764585643},
#         {'value': 0.0, 'timestamp': 1764585943},
#         {'value': 0.0, 'timestamp': 1764586243},
#         {'value': 0.0, 'timestamp': 1764586543},
#         {'value': 0.0, 'timestamp': 1764586843},
#         {'value': 0.0, 'timestamp': 1764587143},
#         {'value': 0.0, 'timestamp': 1764587443},
#         {'value': 0.0, 'timestamp': 1764587743},
#         {'value': 0.0, 'timestamp': 1764588043},
#         {'value': 0.0, 'timestamp': 1764588343},
#         {'value': 0.0, 'timestamp': 1764588643},
#         {'value': 0.0, 'timestamp': 1764588943},
#         {'value': 0.0, 'timestamp': 1764589243},
#         {'value': 0.0, 'timestamp': 1764589543},
#         {'value': 0.0, 'timestamp': 1764589843},
#         {'value': 0.0, 'timestamp': 1764590143},
#         {'value': 0.0, 'timestamp': 1764590443},
#         {'value': 0.0, 'timestamp': 1764590743},
#         {'value': 0.0, 'timestamp': 1764591043},
#         {'value': 0.0, 'timestamp': 1764591343},
#         {'value': 0.0, 'timestamp': 1764591643},
#         {'value': 0.0, 'timestamp': 1764591943},
#         {'value': 0.0, 'timestamp': 1764592243},
#         {'value': 0.0, 'timestamp': 1764592543},
#         {'value': 0.0, 'timestamp': 1764592843},
#         {'value': 0.0, 'timestamp': 1764593143},
#         {'value': 0.0, 'timestamp': 1764593443},
#         {'value': 0.0, 'timestamp': 1764593743},
#         {'value': 0.0, 'timestamp': 1764594043},
#         {'value': 0.0, 'timestamp': 1764594343},
#         {'value': 0.0, 'timestamp': 1764594643},
#         {'value': 0.0, 'timestamp': 1764594943},
#         {'value': 0.0, 'timestamp': 1764595243},
#         {'value': 0.0, 'timestamp': 1764595543},
#         {'value': 0.0, 'timestamp': 1764595843},
#         {'value': 0.0, 'timestamp': 1764596143},
#         {'value': 0.0, 'timestamp': 1764596443},
#         {'value': 0.0, 'timestamp': 1764596743},
#         {'value': 0.0, 'timestamp': 1764597043},
#         {'value': 0.0, 'timestamp': 1764597343},
#         {'value': 0.0, 'timestamp': 1764597643},
#         {'value': 0.0, 'timestamp': 1764597943},
#         {'value': 0.0, 'timestamp': 1764598243},
#         {'value': 0.0, 'timestamp': 1764598543},
#         {'value': 0.0, 'timestamp': 1764598843},
#         {'value': 0.0, 'timestamp': 1764599143},
#         {'value': 0.0, 'timestamp': 1764599443},
#         {'value': 0.0, 'timestamp': 1764599743},
#         {'value': 0.0, 'timestamp': 1764600043},
#         {'value': 0.0, 'timestamp': 1764600343},
#         {'value': 0.0, 'timestamp': 1764600643},
#         {'value': 0.0, 'timestamp': 1764600943},
#         {'value': 0.0, 'timestamp': 1764601243},
#         {'value': 0.0, 'timestamp': 1764601543},
#         {'value': 0.0, 'timestamp': 1764601843},
#         {'value': 0.0, 'timestamp': 1764602143},
#         {'value': 0.0, 'timestamp': 1764602443},
#         {'value': 0.0, 'timestamp': 1764602743},
#         {'value': 0.0, 'timestamp': 1764603043},
#         {'value': 0.0, 'timestamp': 1764603343},
#         {'value': 0.0, 'timestamp': 1764603643},
#         {'value': 0.0, 'timestamp': 1764603943},
#         {'value': 0.0, 'timestamp': 1764604243},
#         {'value': 0.0, 'timestamp': 1764604543},
#         {'value': 0.0, 'timestamp': 1764604843},
#         {'value': 0.0, 'timestamp': 1764605143},
#         {'value': 0.0, 'timestamp': 1764605443},
#         {'value': 0.0, 'timestamp': 1764605743},
#         {'value': 0.0, 'timestamp': 1764606043},
#         {'value': 0.0, 'timestamp': 1764606343},
#         {'value': 0.0, 'timestamp': 1764606643},
#         {'value': 0.0, 'timestamp': 1764606943},
#         {'value': 0.0, 'timestamp': 1764607243},
#         {'value': 0.0, 'timestamp': 1764607543},
#         {'value': 0.0, 'timestamp': 1764607843},
#         {'value': 0.0, 'timestamp': 1764608143},
#         {'value': 0.0, 'timestamp': 1764608443},
#         {'value': 0.0, 'timestamp': 1764608743},
#         {'value': 0.0, 'timestamp': 1764609043},
#         {'value': 0.0, 'timestamp': 1764609343},
#         {'value': 0.0, 'timestamp': 1764609643},
#         {'value': 0.0, 'timestamp': 1764609943},
#         {'value': 0.0, 'timestamp': 1764610243},
#         {'value': 0.0, 'timestamp': 1764610543},
#         {'value': 0.0, 'timestamp': 1764610843},
#         {'value': 0.0, 'timestamp': 1764611143},
#         {'value': 0.0, 'timestamp': 1764611443},
#         {'value': 0.0, 'timestamp': 1764611743},
#         {'value': 0.0, 'timestamp': 1764612043},
#         {'value': 0.0, 'timestamp': 1764612343},
#         {'value': 0.0, 'timestamp': 1764612643},
#         {'value': 0.0, 'timestamp': 1764612943},
#         {'value': 0.0, 'timestamp': 1764613243},
#         {'value': 0.0, 'timestamp': 1764613543},
#         {'value': 0.0, 'timestamp': 1764613843},
#         {'value': 0.0, 'timestamp': 1764614143},
#         {'value': 0.0, 'timestamp': 1764614443},
#         {'value': 0.0, 'timestamp': 1764614743},
#         {'value': 0.0, 'timestamp': 1764615043},
#         {'value': 0.0, 'timestamp': 1764615343},
#         {'value': 0.0, 'timestamp': 1764615643},
#         {'value': 0.0, 'timestamp': 1764615943},
#         {'value': 0.0, 'timestamp': 1764616243},
#         {'value': 0.0, 'timestamp': 1764616543},
#         {'value': 0.0, 'timestamp': 1764616843},
#         {'value': 0.0, 'timestamp': 1764617143},
#         {'value': 0.0, 'timestamp': 1764617443},
#         {'value': 0.0, 'timestamp': 1764617743},
#         {'value': 0.0, 'timestamp': 1764618043},
#         {'value': 0.0, 'timestamp': 1764618343},
#         {'value': 0.0, 'timestamp': 1764618643},
#         {'value': 0.0, 'timestamp': 1764618943},
#         {'value': 0.0, 'timestamp': 1764619243},
#         {'value': 0.0, 'timestamp': 1764619543},
#         {'value': 0.0, 'timestamp': 1764619843},
#         {'value': 0.0, 'timestamp': 1764620143},
#         {'value': 0.0, 'timestamp': 1764620443},
#         {'value': 0.0, 'timestamp': 1764620743},
#         {'value': 0.0, 'timestamp': 1764621043},
#         {'value': 0.0, 'timestamp': 1764621343},
#         {'value': 0.0, 'timestamp': 1764621643},
#         {'value': 0.0, 'timestamp': 1764621943},
#         {'value': 0.0, 'timestamp': 1764622243},
#         {'value': 0.0, 'timestamp': 1764622543},
#         {'value': 0.0, 'timestamp': 1764622843},
#         {'value': 0.0, 'timestamp': 1764623143},
#         {'value': 0.0, 'timestamp': 1764623443},
#         {'value': 0.0, 'timestamp': 1764623743},
#         {'value': 0.0, 'timestamp': 1764624043},
#         {'value': 0.0, 'timestamp': 1764624343},
#         {'value': 0.0, 'timestamp': 1764624643},
#         {'value': 0.0, 'timestamp': 1764624943},
#         {'value': 0.0, 'timestamp': 1764625243},
#         {'value': 0.0, 'timestamp': 1764625543},
#         {'value': 0.0, 'timestamp': 1764625843},
#         {'value': 0.0, 'timestamp': 1764626143},
#         {'value': 0.0, 'timestamp': 1764626443},
#         {'value': 0.0, 'timestamp': 1764626743},
#         {'value': 0.0, 'timestamp': 1764627043},
#         {'value': 0.0, 'timestamp': 1764627343},
#         {'value': 0.0, 'timestamp': 1764627643},
#         {'value': 0.0, 'timestamp': 1764627943},
#         {'value': 0.0, 'timestamp': 1764628243},
#         {'value': 0.0, 'timestamp': 1764628543},
#         {'value': 0.0, 'timestamp': 1764628843},
#         {'value': 0.0, 'timestamp': 1764629143},
#         {'value': 0.0, 'timestamp': 1764629443},
#         {'value': 0.0, 'timestamp': 1764629743}],
#        'subtitle': 'Average',
#        'total': 696.0,
#        'avg': 2.416666666666667,
#        'trend_title': '+2',
#        'trend_direction': 'positive'}},
#      {'type': 'night_rhr',
#       'object': {'day_start_timestamp': 1764543600,
#        'title': 'Resting HR',
#        'values': [{'value': None, 'timestamp': 1764543600}],
#        'subtitle': 'Sleep Time Average'}},
#      {'type': 'movement_index',
#       'object': {'value': 60,
#        'title': 'Movement Index',
#        'day_start_timestamp': 1764543600}}]}],
#   'has_data': True}}

# %%
save_results_as_csv(results, output_dir="./uh_output")
